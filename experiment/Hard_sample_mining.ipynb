# %%
#add sys path
import sys
sys.path.append('/home/atin-ct3/action_recognition')

from experiment.utils import visualize_prediction_with_attention, analyze_multiple_sequences

# Multiple sequences
results = analyze_multiple_sequences(
    # config_path="/home/atin-ct3/action_recognition/config/TimeSformer/RWF_step4.yaml",
    # checkpoint_path="/home/atin-ct3/action_recognition/checkpoints/timesformer_rfw_violence_step4/best_model_acc.pth",
    config_path="/home/atin-ct3/action_recognition/config/X3D/rfw.yaml",
    checkpoint_path="/home/atin-ct3/action_recognition/checkpoints/x3d_rfw_violence/best_model_acc.pth",
    # video_path="/home/atin-ct3/action_recognition/data/Test-Data/cctv_test.mp4",
    video_path="/home/atin-ct3/action_recognition/data/Test-Data/7364334039222.mp4",
    time_points=[29.35, 29.85, 30.35, 30.85],
    save_dir="/home/atin-ct3/action_recognition/outputs/x3d/analysis",
    class_names=["non-violent", "violent"],
    attention_cmap="Reds"
)
# Out:
# ...
# Analyzing sequence 1/4 at 29.35s
# ...
# Loading model: X3D
# Loading model from /home/atin-ct3/action_recognition/checkpoints/x3d_rfw_violence/best_model_acc.pth...
# Loading pretrained x3d_m model from Kinetics-400...
# Using cache found in /home/atin-ct3/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Replacing final layer: 2048 -> 2 classes
# Freezing first 5 blocks out of 6:
#   Block 0: FROZEN
#   Block 1: FROZEN
#   Block 2: FROZEN
#   Block 3: FROZEN
#   Block 4: FROZEN
#   Block 5: TRAINABLE
# Model loaded successfully!
# Extracting sequence from video...
# Sequence: frames 880 to 910
# Time: 29.33s to 30.33s
# Computing attention maps...
# Prediction: non-violent (54.48%)
# Saved visualization to: /home/atin-ct3/action_recognition/outputs/x3d/analysis/cctv_test_t29.4s.png
#
# ...
# Analyzing sequence 2/4 at 29.85s
# ...
# Loading model: X3D
# Loading model from /home/atin-ct3/action_recognition/checkpoints/x3d_rfw_violence/best_model_acc.pth...
# ...
